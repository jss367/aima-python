# %%
from agents4e import *
from notebook import psource

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Constructing Environments

# %% [markdown]
# ## The Environment class
# Is a shell for all environments. It owns **things** and **agents**. It specifies:
# * The thing classes it can hold. These things can be just things (like dirt) or agents (like vacuums that can do stuff)
# * What it can perceive (percept classes -- like what sensors are on my robot?)
# * What it can do. Like if a vacuum sucks up dirt, then it can change the amount of dirt in its environment.
# * Specify a default location for new things, like where more dirt might go.
# * Specify changes we won't allow ("exogenous_change")
# * Tell us if all of the agents are dead
# * Perform one time step in our environmental "game" definition.
#   * Each agent gets to perceive its state
#   * Each agent gets to perform an action
# * Perform a bunch of steps
# * List all the things at a location
# * List some things at a location?
# * Add a thing at a location (or default location)
# * Delete a specified thing

# %%
psource(Environment)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">Environment</span><span class="p">:</span>
#     <span class="sd">&quot;&quot;&quot;Abstract class representing an Environment. &#39;Real&#39; Environment classes</span>
# <span class="sd">    inherit from this. Your Environment will typically need to implement:</span>
# <span class="sd">        percept:           Define the percept that an agent sees.</span>
# <span class="sd">        execute_action:    Define the effects of executing an action.</span>
# <span class="sd">                           Also update the agent.performance slot.</span>
# <span class="sd">    The environment keeps a list of .things and .agents (which is a subset</span>
# <span class="sd">    of .things). Each agent has a .performance slot, initialized to 0.</span>
# <span class="sd">    Each thing has a .location slot, even though some environments may not</span>
# <span class="sd">    need this.&quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">things</span> <span class="o">=</span> <span class="p">[]</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">agents</span> <span class="o">=</span> <span class="p">[]</span>
#
#     <span class="k">def</span> <span class="nf">thing_classes</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="k">return</span> <span class="p">[]</span>  <span class="c1"># List of classes that can go into environment</span>
#
#     <span class="k">def</span> <span class="nf">percept</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">agent</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Return the percept that the agent sees at this point. (Implement this.)&quot;&quot;&quot;</span>
#         <span class="k">raise</span> <span class="ne">NotImplementedError</span>
#
#     <span class="k">def</span> <span class="nf">execute_action</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">agent</span><span class="p">,</span> <span class="n">action</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Change the world to reflect this action. (Implement this.)&quot;&quot;&quot;</span>
#         <span class="k">raise</span> <span class="ne">NotImplementedError</span>
#
#     <span class="k">def</span> <span class="nf">default_location</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">thing</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Default location to place a new thing with unspecified location.&quot;&quot;&quot;</span>
#         <span class="k">return</span> <span class="kc">None</span>
#
#     <span class="k">def</span> <span class="nf">exogenous_chang

# %% [markdown]
# ## The Direction Class
# * Specify a heading (**R**ight, **L**eft, **U**p, **Do**wn)
# * Move Forward

# %%
psource(Direction)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">Direction</span><span class="p">:</span>
#     <span class="sd">&quot;&quot;&quot;A direction class for agents that want to move in a 2D plane</span>
# <span class="sd">        Usage:</span>
# <span class="sd">            d = Direction(&quot;down&quot;)</span>
# <span class="sd">            To change directions:</span>
# <span class="sd">            d = d + &quot;right&quot; or d = d + Direction.R #Both do the same thing</span>
# <span class="sd">            Note that the argument to __add__ must be a string and not a Direction object.</span>
# <span class="sd">            Also, it (the argument) can only be right or left.&quot;&quot;&quot;</span>
#
#     <span class="n">R</span> <span class="o">=</span> <span class="s2">&quot;right&quot;</span>
#     <span class="n">L</span> <span class="o">=</span> <span class="s2">&quot;left&quot;</span>
#     <span class="n">U</span> <span class="o">=</span> <span class="s2">&quot;up&quot;</span>
#     <span class="n">D</span> <span class="o">=</span> <span class="s2">&quot;down&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">direction</span><span class="p">):</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">direction</span> <span class="o">=</span> <span class="n">direction</span>
#
#     <span class="k">def</span> <span class="fm">__add__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">heading</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;</span>
# <span class="sd">        &gt;&gt;&gt; d = Direction(&#39;right&#39;)</span>
# <span class="sd">        &gt;&gt;&gt; l1 = d.__add__(Direction.L)</span>
# <span class="sd">        &gt;&gt;&gt; l2 = d.__add__(Direction.R)</span>
# <span class="sd">        &gt;&gt;&gt; l1.direction</span>
# <span class="sd">        &#39;up&#39;</span>
# <span class="sd">        &gt;&gt;&gt; l2.direction</span>
# <span class="sd">        &#39;down&#39;</span>
# <span class="sd">        &gt;&gt;&gt; d = Direction(&#39;down&#39;)</span>
# <span class="sd">        &gt;&gt;&gt; l1 = d.__add__(&#39;right&#39;)</span>
# <span class="sd">        &gt;&gt;&gt; l2 = d.__add__(&#39;left&#39;)</span>
# <span class="sd">        &gt;&gt;&gt; l1.direction == Direction.L</span>
# <span class="sd">        True</span>
# <span class="sd">        &gt;&gt;&gt; l2.direction == Direction.R</span>
# <span class="sd">        True</span>
# <span class="sd">        &quot;&quot;&quot;</span>
#         <span class="k">if</span> <span class="bp">self</span><span class="o">.</span><span class="n">direction</span> <span class="o">==</span> <span class="bp">self</span><span class="o">.</span><span class="n">R</span><span class="p">:</span>
#             <span class="k">return</span> <span class="p">{</span>
#                 <span class="bp">self</span><span class="o">.</span><span class="n

# %% [markdown]
# ## Environments on a plane XYEnvironment
# * Rectangle with width and height
#   * also initialize a list of observers -- this might be a list provided to the GUI that tells us when things change
# * Things near a location (based on perceptible_distance = 1 or specified radius)
# * Return what things I can see
# * Execute an action
#   * bump against an edge
#   * turn left or right
#   * move forward
#   * grab a thing
#   * release a thing
# * Add observers who get to find out what's happened
# * Move to where I say to move:
#   * If there's an *Obstacle* at my destination I bump. Obstacles are their own trivial class that can be extended into more
#     complicated obstacles that are sets of coordinates.
#   * Otherwise tell all observers the thing moved and remove the thing from the old destination and put it in the new one
#   * Return True/False for whether or not I moved the thing
# * Add a thing to a location. Say what to do if there's a thing there.
# * Check to see if the location some jerk specified is actually in my rectangle.
# * Randomly choose a location in my rectangle, and maybe I'll list some patches that aren't allowed.
# * Delete a thing from the environment. If that thing is an agent drop everything it's holding.
# * Add walls so the vacuum doesn't fall down the stairs. A *Wall* is its own trivial class.
# * Describe the new heading after a turn happens

# %%
psource(XYEnvironment)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">XYEnvironment</span><span class="p">(</span><span class="n">Environment</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;This class is for environments on a 2D plane, with locations</span>
# <span class="sd">    labelled by (x, y) points, either discrete or continuous.</span>
#
# <span class="sd">    Agents perceive things within a radius. Each agent in the</span>
# <span class="sd">    environment has a .location slot which should be a location such</span>
# <span class="sd">    as (0, 1), and a .holding slot, which should be a list of things</span>
# <span class="sd">    that are held.&quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">width</span><span class="o">=</span><span class="mi">10</span><span class="p">,</span> <span class="n">height</span><span class="o">=</span><span class="mi">10</span><span class="p">):</span>
#         <span class="nb">super</span><span class="p">()</span><span class="o">.</span><span class="fm">__init__</span><span class="p">()</span>
#
#         <span class="bp">self</span><span class="o">.</span><span class="n">width</span> <span class="o">=</span> <span class="n">width</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">height</span> <span class="o">=</span> <span class="n">height</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">observers</span> <span class="o">=</span> <span class="p">[]</span>
#         <span class="c1"># Sets iteration start and end (no walls).</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">x_start</span><span class="p">,</span> <span class="bp">self</span><span class="o">.</span><span class="n">y_start</span> <span class="o">=</span> <span class="p">(</span><span class="mi">0</span><span class="p">,</span> <span class="mi">0</span><span class="p">)</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">x_end</span><span class="p">,</span> <span class="bp">self</span><span class="o">.</span><span class="n">y_end</span> <span class="o">=</span> <span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="n">width</span><span class="p">,</span> <span class="bp">self</span><span class="o">.</span><span class="n">height</span><span class="p">)</span>
#
#     <span class="n">perceptible_distance</span> <span class="o">=</span> <span class="mi">1</span>
#
#     <span class="k">def</span> <span class="nf">things_near</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">location</span><span class="p">,</span> <span class="n">radius</span><span class="o">=</span><span class="kc">None</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Return all things within radius of location.&quot;&quot;&quo

# %% [markdown]
# ## GraphicEnvironment(XYEnvironment)
# Handles the GUI

# %%
psource(GraphicEnvironment)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">GraphicEnvironment</span><span class="p">(</span><span class="n">XYEnvironment</span><span class="p">):</span>
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">width</span><span class="o">=</span><span class="mi">10</span><span class="p">,</span> <span class="n">height</span><span class="o">=</span><span class="mi">10</span><span class="p">,</span> <span class="n">boundary</span><span class="o">=</span><span class="kc">True</span><span class="p">,</span> <span class="n">color</span><span class="o">=</span><span class="p">{},</span> <span class="n">display</span><span class="o">=</span><span class="kc">False</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Define all the usual XYEnvironment characteristics,</span>
# <span class="sd">        but initialise a BlockGrid for GUI too.&quot;&quot;&quot;</span>
#         <span class="nb">super</span><span class="p">()</span><span class="o">.</span><span class="fm">__init__</span><span class="p">(</span><span class="n">width</span><span class="p">,</span> <span class="n">height</span><span class="p">)</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">grid</span> <span class="o">=</span> <span class="n">BlockGrid</span><span class="p">(</span><span class="n">width</span><span class="p">,</span> <span class="n">height</span><span class="p">,</span> <span class="n">fill</span><span class="o">=</span><span class="p">(</span><span class="mi">200</span><span class="p">,</span> <span class="mi">200</span><span class="p">,</span> <span class="mi">200</span><span class="p">))</span>
#         <span class="k">if</span> <span class="n">display</span><span class="p">:</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">grid</span><span class="o">.</span><span class="n">show</span><span class="p">()</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">visible</span> <span class="o">=</span> <span class="kc">True</span>
#         <span class="k">else</span><span class="p">:</span>
#             <span class="bp">self</span><span class="o">.</span><span class="n">visible</span> <span class="o">=</span> <span class="kc">False</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">bounded</span> <span class="o">=</span> <span class="n">boundary</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">colors</span> <span class="o">=</span> <span class="n">color</span>
#
#     <span class="k">def</span> <span class="nf">get_world</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Returns all the items in the world in a format</span>
# <span class="sd">        understandable by the ipythonblocks BlockGrid.&quot;&quot;&quot;</s

# %% [markdown]
# ## Example: Let's make a vacuum environment
# <p align="center>
# <img src="images/vacuum.svg">
# </p>
#
# * Initialize Dirt as a Trivial thing
#
# * Start with a trivial 2-grid environment
#
# * Extend the XYEnvironment to **VacuumEnvironment**:
#   * The things are Wall, Dirt, and Four agents (reflux, random, tabledriven, and modelbased) for vacuum behavior. We'll get to those.
#   * The environment knows if an agent (a.k.a. a vacuum) is  standing in dirt and if it will bump into something if it moves forward.
#   * An agent can execute an action:
#     * If the action is suck it gets 100 points (**performance**) and it deletes the dirt, otherwise the performance is -1 and the action is exected according to the agent's logic.

# %% [markdown]
# ### Trivial Vacuum Environment
#
# This one just moves between two grids -- no headings or looking for obstacles is needed, and it can suck if the floor is dirty.

# %%
psource(TrivialVacuumEnvironment)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">TrivialVacuumEnvironment</span><span class="p">(</span><span class="n">Environment</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;This environment has two locations, A and B. Each can be Dirty</span>
# <span class="sd">    or Clean. The agent perceives its location and the location&#39;s</span>
# <span class="sd">    status. This serves as an example of how to implement a simple</span>
# <span class="sd">    Environment.&quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="nb">super</span><span class="p">()</span><span class="o">.</span><span class="fm">__init__</span><span class="p">()</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">status</span> <span class="o">=</span> <span class="p">{</span><span class="n">loc_A</span><span class="p">:</span> <span class="n">random</span><span class="o">.</span><span class="n">choice</span><span class="p">([</span><span class="s1">&#39;Clean&#39;</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">]),</span>
#                        <span class="n">loc_B</span><span class="p">:</span> <span class="n">random</span><span class="o">.</span><span class="n">choice</span><span class="p">([</span><span class="s1">&#39;Clean&#39;</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">])}</span>
#
#     <span class="k">def</span> <span class="nf">thing_classes</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="k">return</span> <span class="p">[</span><span class="n">Wall</span><span class="p">,</span> <span class="n">Dirt</span><span class="p">,</span> <span class="n">ReflexVacuumAgent</span><span class="p">,</span> <span class="n">RandomVacuumAgent</span><span class="p">,</span> <span class="n">TableDrivenVacuumAgent</span><span class="p">,</span> <span class="n">ModelBasedVacuumAgent</span><span class="p">]</span>
#
#     <span class="k">def</span> <span class="nf">percept</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">agent</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Returns the agent&#39;s location, and the location status (Dirty/Clean).&quot;&quot;&quot;</span>
#         <span class="k">return</span> <span class="n">agent</span><span class="o">.</span><span class="n">location</span><span class="p">,</span> <span class="bp">self</span><span class="o">.</span><span class="n">status</span><span class="p">[</span><span class="n">agent</span><span class="o">.</span><span class="n">location</span><span class="p">]</span>
#
#     <span class="k">def</span> <span class="nf">execute_action</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">agent</s

# %% [markdown]
# ### Nontrivial vacuum environment
#
# Note that this environment can
# * Tell if the floor is dirty or not
# * Tell if the agent is bumping against an obstacle
# * Execute the "suck" action and assign an award **if** that action is successful/possible
#
# You'll see the `execute_action` refers to the XYEnvironment that already handled how the robot vacuum will handle movement (checking for obstacles).
#
# You'll also see that this basic environment can handle multiple types of vacuum agents, and we're going to pay attention to the differing behaviors of allowed agents.
#
# Also let's pay attention to rewards. There's a "NoOp" action that is neutral. Otherwise, the only reward is actually picking up dirt (+100) and the costs of movement are a reward of -1.

# %%
psource(VacuumEnvironment)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">VacuumEnvironment</span><span class="p">(</span><span class="n">XYEnvironment</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;The environment of [Ex. 2.12]. Agent perceives dirty or clean,</span>
# <span class="sd">    and bump (into obstacle) or not; 2D discrete world of unknown size;</span>
# <span class="sd">    performance measure is 100 for each dirt cleaned, and -1 for</span>
# <span class="sd">    each turn taken.&quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">width</span><span class="o">=</span><span class="mi">10</span><span class="p">,</span> <span class="n">height</span><span class="o">=</span><span class="mi">10</span><span class="p">):</span>
#         <span class="nb">super</span><span class="p">()</span><span class="o">.</span><span class="fm">__init__</span><span class="p">(</span><span class="n">width</span><span class="p">,</span> <span class="n">height</span><span class="p">)</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">add_walls</span><span class="p">()</span>
#
#     <span class="k">def</span> <span class="nf">thing_classes</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="k">return</span> <span class="p">[</span><span class="n">Wall</span><span class="p">,</span> <span class="n">Dirt</span><span class="p">,</span> <span class="n">XYReflexVacuumAgent</span><span class="p">,</span> <span class="n">ReflexVacuumAgent</span><span class="p">,</span> <span class="n">RandomVacuumAgent</span><span class="p">,</span>
#                 <span class="n">TableDrivenVacuumAgent</span><span class="p">,</span> <span class="n">ModelBasedVacuumAgent</span><span class="p">]</span>
#
#     <span class="k">def</span> <span class="nf">percept</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">agent</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;The percept is a tuple of (&#39;Dirty&#39; or &#39;Clean&#39;, &#39;Bump&#39; or &#39;None&#39;).</span>
# <span class="sd">        Unlike the TrivialVacuumEnvironment, location is NOT perceived.&quot;&quot;&quot;</span>
#         <span class="n">status</span> <span class="o">=</span> <span class="p">(</span><span class="s1">&#39;Dirty&#39;</span> <span class="k">if</span> <span class="bp">self</span><span class="o">.</span><span class="n">some_things_at</span><span class="p">(</span>
#             <span class="n">agent</span><span class="o">.</span><span class="n">location</span><span class="p">,</span> <span class="n">Dirt</span><span class="p">)</span> <span class="k">else</span> <span class="s1">&#39;Clean&#39;</span><span class="p">)</span>
#         <span class="n">bump</span> <span class="o">=</span> <span class="p">(</span><span class="s1">&#39;B

# %% [markdown]
# # Defining Agents

# %% [markdown]
# ## An agent is a thing inside your environnment
#
# The initial **Thing** class is really just a shell. We'll want to define whether the thing is *alive*, how to display our thing's state, and how to display maybe a picture of our thing, like if our thing were a function we could make a picture. The **Agent** class is a subclass that performs actions based on what it perceives in the environment. To keep things general, this agent class will take in a user-defined FUNCTION that turns perceptions into actions.

# %%
psource(Thing)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">Thing</span><span class="p">:</span>
#     <span class="sd">&quot;&quot;&quot;This represents any physical object that can appear in an Environment.</span>
# <span class="sd">    You subclass Thing to get the things you want. Each thing can have a</span>
# <span class="sd">    .__name__  slot (used for output only).&quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__repr__</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="k">return</span> <span class="s1">&#39;&lt;</span><span class="si">{}</span><span class="s1">&gt;&#39;</span><span class="o">.</span><span class="n">format</span><span class="p">(</span><span class="nb">getattr</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="s1">&#39;__name__&#39;</span><span class="p">,</span> <span class="bp">self</span><span class="o">.</span><span class="vm">__class__</span><span class="o">.</span><span class="vm">__name__</span><span class="p">))</span>
#
#     <span class="k">def</span> <span class="nf">is_alive</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Things that are &#39;alive&#39; should return true.&quot;&quot;&quot;</span>
#         <span class="k">return</span> <span class="nb">hasattr</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="s1">&#39;alive&#39;</span><span class="p">)</span> <span class="ow">and</span> <span class="bp">self</span><span class="o">.</span><span class="n">alive</span>
#
#     <span class="k">def</span> <span class="nf">show_state</span><span class="p">(</span><span class="bp">self</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Display the agent&#39;s internal state. Subclasses should override.&quot;&quot;&quot;</span>
#         <span class="nb">print</span><span class="p">(</span><span class="s2">&quot;I don&#39;t know how to show_state.&quot;</span><span class="p">)</span>
#
#     <span class="k">def</span> <span class="nf">display</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">canvas</span><span class="p">,</span> <span class="n">x</span><span class="p">,</span> <span class="n">y</span><span class="p">,</span> <span class="n">width</span><span class="p">,</span> <span class="n">height</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Display an image of this Thing on the canvas.&quot;&quot;&quot;</span>
#         <span class="c1"># Do we need this?</span>
#         <span class="k">pass</span>
# </pre></div>
# </body>
# </html>

# %%
psource(Agent)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">class</span> <span class="nc">Agent</span><span class="p">(</span><span class="n">Thing</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;An Agent is a subclass of Thing with one required slot,</span>
# <span class="sd">    .program, which should hold a function that takes one argument, the</span>
# <span class="sd">    percept, and returns an action. (What counts as a percept or action</span>
# <span class="sd">    will depend on the specific environment in which the agent exists.)</span>
# <span class="sd">    Note that &#39;program&#39; is a slot, not a method. If it were a method,</span>
# <span class="sd">    then the program could &#39;cheat&#39; and look at aspects of the agent.</span>
# <span class="sd">    It&#39;s not supposed to do that: the program can only look at the</span>
# <span class="sd">    percepts. An agent program that needs a model of the world (and of</span>
# <span class="sd">    the agent itself) will have to build and maintain its own model.</span>
# <span class="sd">    There is an optional slot, .performance, which is a number giving</span>
# <span class="sd">    the performance measure of the agent in its environment.&quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="fm">__init__</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">program</span><span class="o">=</span><span class="kc">None</span><span class="p">,</span> <span class="n">direction</span> <span class="o">=</span> <span class="kc">None</span><span class="p">):</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">alive</span> <span class="o">=</span> <span class="kc">True</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">bump</span> <span class="o">=</span> <span class="kc">False</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">holding</span> <span class="o">=</span> <span class="p">[]</span>
#         <span class="bp">self</span><span class="o">.</span><span class="n">performance</span> <span class="o">=</span> <span class="mi">0</span>
#         <span class="k">if</span> <span class="n">program</span> <span class="ow">is</span> <span class="kc">None</span><span class="p">:</span>
#                 <span class="c1">#  or \</span>
#                 <span class="c1"># (not isinstance(program, collections.abc.Callable) \</span>
#                 <span class="c1"># and not isinstance(program, function)):</span>
#             <span class="nb">print</span><span class="p">(</span><span class="s2">&quot;Can&#39;t find a valid program for </span><span class="si">{}</span><span class="s2">, falling back to default.&quot;</span><span class="o">.</span><span class="n">format</span><span class="p">(</span><span class="bp">self</span><span class="o">.</span><span class="vm">__class__</span><span class="o">.</span><span class="vm">__name__</span><span class="p">))</span>
#
#             <span c

# %% [markdown]
# ## How do we know what the agent did?

# %%
psource(TraceAgent)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">TraceAgent</span><span class="p">(</span><span class="n">agent</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;Wrap the agent&#39;s program to print its input and output. This will let</span>
# <span class="sd">    you see what the agent is doing in the environment.&quot;&quot;&quot;</span>
#     <span class="n">old_program</span> <span class="o">=</span> <span class="n">agent</span><span class="o">.</span><span class="n">program</span>
#
#     <span class="k">def</span> <span class="nf">new_program</span><span class="p">(</span><span class="n">percept</span><span class="p">):</span>
#         <span class="n">action</span> <span class="o">=</span> <span class="n">old_program</span><span class="p">(</span><span class="n">percept</span><span class="p">)</span>
#         <span class="nb">print</span><span class="p">(</span><span class="s1">&#39;</span><span class="si">{}</span><span class="s1"> perceives </span><span class="si">{}</span><span class="s1"> and does </span><span class="si">{}</span><span class="s1"> with performance </span><span class="si">{}</span><span class="s1">&#39;</span>\
#             <span class="o">.</span><span class="n">format</span><span class="p">(</span><span class="n">agent</span><span class="p">,</span> <span class="n">percept</span><span class="p">,</span> <span class="n">action</span><span class="p">,</span> <span class="n">agent</span><span class="o">.</span><span class="n">performance</span><span class="p">))</span>
#         <span class="k">return</span> <span class="n">action</span>
#
#     <span class="n">agent</span><span class="o">.</span><span class="n">program</span> <span class="o">=</span> <span class="n">new_program</span>
#     <span class="k">return</span> <span class="n">agent</span>
# </pre></div>
# </body>
# </html>

# %% [markdown]
# ## BORING AGENT EXAMPLES

# %% [markdown]
# ### Random

# %%
psource(RandomAgentProgram)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">RandomAgentProgram</span><span class="p">(</span><span class="n">actions</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;An agent that chooses an action at random, ignoring all percepts.</span>
# <span class="sd">    &gt;&gt;&gt; list = [&#39;Right&#39;, &#39;Left&#39;, &#39;Suck&#39;, &#39;NoOp&#39;]</span>
# <span class="sd">    &gt;&gt;&gt; program = RandomAgentProgram(list)</span>
# <span class="sd">    &gt;&gt;&gt; agent = Agent(program)</span>
# <span class="sd">    &gt;&gt;&gt; environment = TrivialVacuumEnvironment()</span>
# <span class="sd">    &gt;&gt;&gt; environment.add_thing(agent)</span>
# <span class="sd">    &gt;&gt;&gt; environment.run()</span>
# <span class="sd">    &gt;&gt;&gt; environment.status == {(1, 0): &#39;Clean&#39; , (0, 0): &#39;Clean&#39;}</span>
# <span class="sd">    True</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#     <span class="k">return</span> <span class="k">lambda</span> <span class="n">percept</span><span class="p">:</span> <span class="n">random</span><span class="o">.</span><span class="n">choice</span><span class="p">(</span><span class="n">actions</span><span class="p">)</span>
# </pre></div>
# </body>
# </html>

# %%
psource(RandomVacuumAgent)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">RandomVacuumAgent</span><span class="p">():</span>
#     <span class="sd">&quot;&quot;&quot;Randomly choose one of the actions from the vacuum environment.</span>
# <span class="sd">    &gt;&gt;&gt; agent = RandomVacuumAgent()</span>
# <span class="sd">    &gt;&gt;&gt; environment = TrivialVacuumEnvironment()</span>
# <span class="sd">    &gt;&gt;&gt; environment.add_thing(agent)</span>
# <span class="sd">    &gt;&gt;&gt; environment.run()</span>
# <span class="sd">    &gt;&gt;&gt; environment.status == {(1,0):&#39;Clean&#39; , (0,0) : &#39;Clean&#39;}</span>
# <span class="sd">    True</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#     <span class="k">return</span> <span class="n">Agent</span><span class="p">(</span><span class="n">RandomAgentProgram</span><span class="p">([</span><span class="s1">&#39;Right&#39;</span><span class="p">,</span> <span class="s1">&#39;Left&#39;</span><span class="p">,</span> <span class="s1">&#39;Suck&#39;</span><span class="p">,</span> <span class="s1">&#39;NoOp&#39;</span><span class="p">]))</span>
# </pre></div>
# </body>
# </html>

# %% [markdown]
# ### Table-driven agents

# %%
psource(TableDrivenAgentProgram)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">TableDrivenAgentProgram</span><span class="p">(</span><span class="n">table</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;</span>
# <span class="sd">    [Figure 2.7]</span>
# <span class="sd">    This agent selects an action based on the percept sequence.</span>
# <span class="sd">    It is practical only for tiny domains.</span>
# <span class="sd">    To customize it, provide as table a dictionary of all</span>
# <span class="sd">    {percept_sequence:action} pairs.</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#     <span class="n">percepts</span> <span class="o">=</span> <span class="p">[]</span>
#
#     <span class="k">def</span> <span class="nf">program</span><span class="p">(</span><span class="n">percept</span><span class="p">):</span>
#         <span class="n">percepts</span><span class="o">.</span><span class="n">append</span><span class="p">(</span><span class="n">percept</span><span class="p">)</span>
#         <span class="n">action</span> <span class="o">=</span> <span class="n">table</span><span class="o">.</span><span class="n">get</span><span class="p">(</span><span class="nb">tuple</span><span class="p">(</span><span class="n">percepts</span><span class="p">))</span>
#         <span class="k">return</span> <span class="n">action</span>
#
#     <span class="k">return</span> <span class="n">program</span>
# </pre></div>
# </body>
# </html>

# %%
psource(TableDrivenVacuumAgent)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">TableDrivenVacuumAgent</span><span class="p">():</span>
#     <span class="sd">&quot;&quot;&quot;Tabular approach towards vacuum world as mentioned in [Figure 2.3]</span>
# <span class="sd">    &gt;&gt;&gt; agent = TableDrivenVacuumAgent()</span>
# <span class="sd">    &gt;&gt;&gt; environment = TrivialVacuumEnvironment()</span>
# <span class="sd">    &gt;&gt;&gt; environment.add_thing(agent)</span>
# <span class="sd">    &gt;&gt;&gt; environment.run()</span>
# <span class="sd">    &gt;&gt;&gt; environment.status == {(1,0):&#39;Clean&#39; , (0,0) : &#39;Clean&#39;}</span>
# <span class="sd">    True</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#     <span class="n">table</span> <span class="o">=</span> <span class="p">{((</span><span class="n">loc_A</span><span class="p">,</span> <span class="s1">&#39;Clean&#39;</span><span class="p">),):</span> <span class="s1">&#39;Right&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_A</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">),):</span> <span class="s1">&#39;Suck&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_B</span><span class="p">,</span> <span class="s1">&#39;Clean&#39;</span><span class="p">),):</span> <span class="s1">&#39;Left&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_B</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">),):</span> <span class="s1">&#39;Suck&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_A</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">),</span> <span class="p">(</span><span class="n">loc_A</span><span class="p">,</span> <span class="s1">&#39;Clean&#39;</span><span class="p">)):</span> <span class="s1">&#39;Right&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_A</span><span class="p">,</span> <span class="s1">&#39;Clean&#39;</span><span class="p">),</span> <span class="p">(</span><span class="n">loc_B</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">)):</span> <span class="s1">&#39;Suck&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_B</span><span class="p">,</span> <span class="s1">&#39;Clean&#39;</span><span class="p">),</span> <span class="p">(</span><span class="n">loc_A</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">)):</span> <span class="s1">&#39;Suck&#39;</span><span class="p">,</span>
#              <span class="p">((</span><span class="n">loc_B</span><span class="p">,</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">),</span> <span class="p">(</span><span class="n">loc_B</span><span class="p">,</span> <span class="s1">&#39;Clean&#39;</span><span cl

# %% [markdown]
# Can you imagine making a table for the 2D environment? This is just not scalable!

# %% [markdown]
# ## REFLEX AGENTS
#
# Here's the take-away: a reflex agent has rules for its behavior based on what it perceives in its environment. In reinforcement learning, we typically call those rules a **policy** for actions.

# %%
psource(SimpleReflexAgentProgram)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">SimpleReflexAgentProgram</span><span class="p">(</span><span class="n">rules</span><span class="p">,</span> <span class="n">interpret_input</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;</span>
# <span class="sd">    [Figure 2.10]</span>
# <span class="sd">    This agent takes action based solely on the percept.</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="nf">program</span><span class="p">(</span><span class="n">percept</span><span class="p">):</span>
#         <span class="n">state</span> <span class="o">=</span> <span class="n">interpret_input</span><span class="p">(</span><span class="n">percept</span><span class="p">)</span>
#         <span class="n">rule</span> <span class="o">=</span> <span class="n">rule_match</span><span class="p">(</span><span class="n">state</span><span class="p">,</span> <span class="n">rules</span><span class="p">)</span>
#         <span class="n">action</span> <span class="o">=</span> <span class="n">rule</span><span class="o">.</span><span class="n">action</span>
#         <span class="k">return</span> <span class="n">action</span>
#
#     <span class="k">return</span> <span class="n">program</span>
# </pre></div>
# </body>
# </html>

# %% [markdown]
# ### The ReflexVacuumAgent
#
#
# <p align="center">
# <img src="images/simple_reflex_agent.jpg">
# </p>
#
# Perceive the location and status
# * If the status is dirty, suck
# * Otherwise move to the other location
#
# #### Trivial Reflex Vacuum Agent

# %%
psource(ReflexVacuumAgent)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">ReflexVacuumAgent</span><span class="p">():</span>
#     <span class="sd">&quot;&quot;&quot;</span>
# <span class="sd">    [Figure 2.8]</span>
# <span class="sd">    A reflex agent for the two-state vacuum environment.</span>
# <span class="sd">    &gt;&gt;&gt; agent = ReflexVacuumAgent()</span>
# <span class="sd">    &gt;&gt;&gt; environment = TrivialVacuumEnvironment()</span>
# <span class="sd">    &gt;&gt;&gt; environment.add_thing(agent)</span>
# <span class="sd">    &gt;&gt;&gt; environment.run()</span>
# <span class="sd">    &gt;&gt;&gt; environment.status == {(1,0):&#39;Clean&#39; , (0,0) : &#39;Clean&#39;}</span>
# <span class="sd">    True</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="nf">program</span><span class="p">(</span><span class="n">percept</span><span class="p">):</span>
#         <span class="n">location</span><span class="p">,</span> <span class="n">status</span> <span class="o">=</span> <span class="n">percept</span>
#         <span class="k">if</span> <span class="n">status</span> <span class="o">==</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;Suck&#39;</span>
#         <span class="k">elif</span> <span class="n">location</span> <span class="o">==</span> <span class="n">loc_A</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;Right&#39;</span>
#         <span class="k">elif</span> <span class="n">location</span> <span class="o">==</span> <span class="n">loc_B</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;Left&#39;</span>
#
#     <span class="k">return</span> <span class="n">Agent</span><span class="p">(</span><span class="n">program</span><span class="p">)</span>
# </pre></div>
# </body>
# </html>

# %% [markdown]
# ##### Running the trivial reflex vacuum agent

# %%
agent = ReflexVacuumAgent()
dirt = Dirt()
environment = TrivialVacuumEnvironment()
environment.add_thing(agent)
environment.status
# Out:
# {(0, 0): 'Dirty', (1, 0): 'Clean'}

# %%
environment.run()
environment.status
# Out:
# {(0, 0): 'Clean', (1, 0): 'Clean'}

# %% [markdown]
# #### Nontrivial Vacuum Agent
#
# I wanted to think this through before I saw their solution.
#
# So maybe we'd say
# * if the location is dirty, suck (performance +100)
# * Otherwise if no bump move forward (performance -1)
# * Otherwise move heading to the left or right -- probably want to be random (performance -1)
#
# The agent itself is tracking its direction and an internal concept of location using the "Direction" class that's defined above. That class is already integrated into the XYEnvironment defining `TurnLeft`, `TurnRight`, and `Forward`.

# %%
import random
from agents4e import Agent

def XYReflexVacuumAgent():
    """ Extend trivial example

    The XY environment returns the state
    ('Dirty'/'Clean', 'Bump'/'None')

    The agent itself is tracking its location.
    
    """

    def program(percept):
        status, bump = percept
        if status == 'Dirty':
            return 'Suck'
        elif bump == 'Bump': 
            # return 'TurnLeft'
            return random.choice(['TurnLeft', 'TurnRight'])
        else:
            return 'Forward'


    return Agent(program = program, \
        direction = Direction(random.choice(["left", "right", "up", "down"])))

# %%
TraceAgent(vacuum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\elsa.schaefer\Documents\dev\aima\aima-python\aibc_agents.elsa.ipynb Cell 39' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elsa.schaefer/Documents/dev/aima/aima-python/aibc_agents.elsa.ipynb#ch0000038?line=0'>1</a> TraceAgent(vacuum)
#
# NameError: name 'vacuum' is not defined

# %%
dirt = Dirt()
dirt.is_alive()
# Out:
# False

# %%
vacuum = XYReflexVacuumAgent()
environment = VacuumEnvironment()
environment.add_thing(vacuum)
for idx in range(10):
    dirt = Dirt()
    environment.add_thing(dirt, [random.randint(0,9),random.randint(0,9)])
vacuum.performance
# Out:
# 0

# %%
def stat(tf):
    return "DIRT" if tf == True else " c  "

def show_dirt(env):
    for idx in range(10):
        dirt_print = [stat(env.some_things_at([idx, j], Dirt)) for j in range(10)]
        print(dirt_print)

# %%
show_dirt(environment)
# Out:
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', 'DIRT', 'DIRT', ' c  ', ' c  ', 'DIRT', 'DIRT', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', 'DIRT', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', 'DIRT', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', 'DIRT', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', 'DIRT', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', 'DIRT', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']

# %%
TraceAgent(vacuum)
environment.run(steps = 5000)
# Out:
# <Agent> perceives ('Clean', 'None') and does Forward with performance 0
# <Agent> perceives ('Clean', 'None') and does Forward with performance -1
# <Agent> perceives ('Dirty', 'None') and does Suck with performance -2
# <Agent> perceives ('Clean', 'None') and does Forward with performance 97
# <Agent> perceives ('Clean', 'None') and does Forward with performance 96
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 95
# <Agent> perceives ('Clean', 'None') and does Forward with performance 94
# <Agent> perceives ('Clean', 'None') and does Forward with performance 93
# <Agent> perceives ('Clean', 'None') and does Forward with performance 92
# <Agent> perceives ('Clean', 'None') and does Forward with performance 91
# <Agent> perceives ('Clean', 'None') and does Forward with performance 90
# <Agent> perceives ('Clean', 'None') and does Forward with performance 89
# <Agent> perceives ('Clean', 'None') and does Forward with performance 88
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 87
# <Agent> perceives ('Clean', 'None') and does Forward with performance 86
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 85
# <Agent> perceives ('Clean', 'None') and does Forward with performance 84
# <Agent> perceives ('Clean', 'None') and does Forward with performance 83
# <Agent> perceives ('Clean', 'None') and does Forward with performance 82
# <Agent> perceives ('Clean', 'None') and does Forward with performance 81
# <Agent> perceives ('Clean', 'None') and does Forward with performance 80
# <Agent> perceives ('Clean', 'None') and does Forward with performance 79
# <Agent> perceives ('Clean', 'None') and does Forward with performance 78
# <Agent> perceives ('Clean', 'None') and does Forward with performance 77
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 76
# <Agent> perceives ('Clean', 'None') and does Forward with performance 75
# <Agent> perceives ('Dirty', 'None') and does Suck with performance 74
# <Agent> perceives ('Clean', 'None') and does Forward with performance 173
# <Agent> perceives ('Clean', 'None') and does Forward with performance 172
# <Agent> perceives ('Clean', 'None') and does Forward with performance 171
# <Agent> perceives ('Dirty', 'None') and does Suck with performance 170
# <Agent> perceives ('Clean', 'None') and does Forward with performance 269
# <Agent> perceives ('Clean', 'None') and does Forward with performance 268
# <Agent> perceives ('Clean', 'None') and does Forward with performance 267
# <Agent> perceives ('Clean', 'None') and does Forward with performance 266
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 265
# <Agent> perceives ('Clean', 'None') and does Forward with performance 264
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 263
# <Agent> perceives ('Clean', 'None') and does Forward with performance 262
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 261
# <Agent> perceives ('Clean', 'None') and does Forward with performance 260
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 259
# <Agent> perceives ('Clean', 'None') and does Forward with performance 258
# <Agent> perceives ('Clean', 'None') and does Forward with performance 257
# <Agent> perceives ('Clean', 'None') and does Forward with performance 256
# <Agent> perceives ('Clean', 'None') and does Forward with performance 255
# <Agent> perceives ('Clean', 'None') and does Forward with performance 254
# <Agent> perceives ('Clean', 'None') and does Forward with performance 253
# <Agent> perceives ('Clean', 'None') and does Forward with performance 252
# <Agent> perceives ('Clean', 'None') and does Forward with performance 251
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 250
# <Agent> perceives ('Clean', 'None') and does Forward with performance 249
# <Agent> perceives ('Clean', 'None') and does Forward with performance 248
# <Agent> perceives ('Clean', 'None') and does Forward with performance 247
# <Agent> perceives ('Clean', 'None') and does Forward with performance 246
# <Agent> perceives ('Clean', 'None') and does Forward with performance 245
# <Agent> perceives ('Clean', 'None') and does Forward with performance 244
# <Agent> perceives ('Clean', 'None') and does Forward with performance 243
# <Agent> perceives ('Clean', 'None') and does Forward with performance 242
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 241
# <Agent> perceives ('Clean', 'None') and does Forward with performance 240
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 239
# <Agent> perceives ('Clean', 'None') and does Forward with performance 238
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 237
# <Agent> perceives ('Clean', 'None') and does Forward with performance 236
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 235
# <Agent> perceives ('Clean', 'None') and does Forward with performance 234
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 233
# <Agent> perceives ('Clean', 'None') and does Forward with performance 232
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 231
# <Agent> perceives ('Clean', 'None') and does Forward with performance 230
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 229
# <Agent> perceives ('Clean', 'None') and does Forward with performance 228
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 227
# <Agent> perceives ('Clean', 'None') and does Forward with performance 226
# <Agent> perceives ('Clean', 'None') and does Forward with performance 225
# <Agent> perceives ('Clean', 'None') and does Forward with performance 224
# <Agent> perceives ('Clean', 'None') and does Forward with performance 223
# <Agent> perceives ('Clean', 'None') and does Forward with performance 222
# <Agent> perceives ('Clean', 'None') and does Forward with performance 221
# <Agent> perceives ('Clean', 'None') and does Forward with performance 220
# <Agent> perceives ('Clean', 'None') and does Forward with performance 219
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 218
# <Agent> perceives ('Clean', 'None') and does Forward with performance 217
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 216
# <Agent> perceives ('Clean', 'None') and does Forward with performance 215
# <Agent> perceives ('Clean', 'None') and does Forward with performance 214
# <Agent> perceives ('Clean', 'None') and does Forward with performance 213
# <Agent> perceives ('Clean', 'None') and does Forward with performance 212
# <Agent> perceives ('Clean', 'None') and does Forward with performance 211
# <Agent> perceives ('Clean', 'None') and does Forward with performance 210
# <Agent> perceives ('Clean', 'None') and does Forward with performance 209
# <Agent> perceives ('Clean', 'None') and does Forward with performance 208
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 207
# <Agent> perceives ('Clean', 'None') and does Forward with performance 206
# <Agent> perceives ('Clean', 'None') and does Forward with performance 205
# <Agent> perceives ('Clean', 'None') and does Forward with performance 204
# <Agent> perceives ('Clean', 'None') and does Forward with performance 203
# <Agent> perceives ('Clean', 'None') and does Forward with performance 202
# <Agent> perceives ('Clean', 'None') and does Forward with performance 201
# <Agent> perceives ('Dirty', 'None') and does Suck with performance 200
# <Agent> perceives ('Clean', 'None') and does Forward with performance 299
# <Agent> perceives ('Clean', 'None') and does Forward with performance 298
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 297
# <Agent> perceives ('Clean', 'None') and does Forward with performance 296
# <Agent> perceives ('Clean', 'None') and does Forward with performance 295
# <Agent> perceives ('Clean', 'None') and does Forward with performance 294
# <Agent> perceives ('Clean', 'None') and does Forward with performance 293
# <Agent> perceives ('Clean', 'None') and does Forward with performance 292
# <Agent> perceives ('Clean', 'None') and does Forward with performance 291
# <Agent> perceives ('Clean', 'None') and does Forward with performance 290
# <Agent> perceives ('Clean', 'None') and does Forward with performance 289
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 288
# <Agent> perceives ('Clean', 'None') and does Forward with performance 287
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 286
# <Agent> perceives ('Clean', 'None') and does Forward with performance 285
# <Agent> perceives ('Clean', 'None') and does Forward with performance 284
# <Agent> perceives ('Clean', 'None') and does Forward with performance 283
# <Agent> perceives ('Clean', 'None') and does Forward with performance 282
# <Agent> perceives ('Clean', 'None') and does Forward with performance 281
# <Agent> perceives ('Clean', 'None') and does Forward with performance 280
# <Agent> perceives ('Clean', 'None') and does Forward with performance 279
# <Agent> perceives ('Clean', 'None') and does Forward with performance 278
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 277
# <Agent> perceives ('Clean', 'None') and does Forward with performance 276
# <Agent> perceives ('Clean', 'None') and does Forward with performance 275
# <Agent> perceives ('Clean', 'None') and does Forward with performance 274
# <Agent> perceives ('Clean', 'None') and does Forward with performance 273
# <Agent> perceives ('Clean', 'None') and does Forward with performance 272
# <Agent> perceives ('Clean', 'None') and does Forward with performance 271
# <Agent> perceives ('Clean', 'None') and does Forward with performance 270
# <Agent> perceives ('Clean', 'None') and does Forward with performance 269
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 268
# <Agent> perceives ('Clean', 'None') and does Forward with performance 267
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 266
# <Agent> perceives ('Clean', 'None') and does Forward with performance 265
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 264
# <Agent> perceives ('Clean', 'None') and does Forward with performance 263
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 262
# <Agent> perceives ('Clean', 'None') and does Forward with performance 261
# <Agent> perceives ('Clean', 'None') and does Forward with performance 260
# <Agent> perceives ('Clean', 'None') and does Forward with performance 259
# <Agent> perceives ('Clean', 'None') and does Forward with performance 258
# <Agent> perceives ('Clean', 'None') and does Forward with performance 257
# <Agent> perceives ('Clean', 'None') and does Forward with performance 256
# <Agent> perceives ('Clean', 'None') and does Forward with performance 255
# <Agent> perceives ('Clean', 'None') and does Forward with performance 254
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 253
# <Agent> perceives ('Clean', 'None') and does Forward with performance 252
# <Agent> perceives ('Clean', 'None') and does Forward with performance 251
# <Agent> perceives ('Clean', 'None') and does Forward with performance 250
# <Agent> perceives ('Clean', 'None') and does Forward with performance 249
# <Agent> perceives ('Clean', 'None') and does Forward with performance 248
# <Agent> perceives ('Clean', 'None') and does Forward with performance 247
# <Agent> perceives ('Clean', 'None') and does Forward with performance 246
# <Agent> perceives ('Clean', 'None') and does Forward with performance 245
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 244
# <Agent> perceives ('Clean', 'None') and does Forward with performance 243
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 242
# <Agent> perceives ('Clean', 'None') and does Forward with performance 241
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 240
# <Agent> perceives ('Clean', 'None') and does Forward with performance 239
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 238
# <Agent> perceives ('Clean', 'None') and does Forward with performance 237
# <Agent> perceives ('Clean', 'None') and does Forward with performance 236
# <Agent> perceives ('Clean', 'None') and does Forward with performance 235
# <Agent> perceives ('Clean', 'None') and does Forward with performance 234
# <Agent> perceives ('Clean', 'None') and does Forward with performance 233
# <Agent> perceives ('Clean', 'None') and does Forward with performance 232
# <Agent> perceives ('Clean', 'None') and does Forward with performance 231
# <Agent> perceives ('Clean', 'None') and does Forward with performance 230
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 229
# <Agent> perceives ('Clean', 'None') and does Forward with performance 228
# <Agent> perceives ('Clean', 'None') and does Forward with performance 227
# <Agent> perceives ('Clean', 'None') and does Forward with performance 226
# <Agent> perceives ('Clean', 'None') and does Forward with performance 225
# <Agent> perceives ('Clean', 'None') and does Forward with performance 224
# <Agent> perceives ('Clean', 'None') and does Forward with performance 223
# <Agent> perceives ('Clean', 'None') and does Forward with performance 222
# <Agent> perceives ('Clean', 'None') and does Forward with performance 221
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 220
# <Agent> perceives ('Clean', 'None') and does Forward with performance 219
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 218
# <Agent> perceives ('Clean', 'None') and does Forward with performance 217
# <Agent> perceives ('Clean', 'None') and does Forward with performance 216
# <Agent> perceives ('Clean', 'None') and does Forward with performance 215
# <Agent> perceives ('Clean', 'None') and does Forward with performance 214
# <Agent> perceives ('Clean', 'None') and does Forward with performance 213
# <Agent> perceives ('Clean', 'None') and does Forward with performance 212
# <Agent> perceives ('Clean', 'None') and does Forward with performance 211
# <Agent> perceives ('Clean', 'None') and does Forward with performance 210
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 209
# <Agent> perceives ('Clean', 'None') and does Forward with performance 208
# <Agent> perceives ('Clean', 'None') and does Forward with performance 207
# <Agent> perceives ('Clean', 'None') and does Forward with performance 206
# <Agent> perceives ('Clean', 'None') and does Forward with performance 205
# <Agent> perceives ('Clean', 'None') and does Forward with performance 204
# <Agent> perceives ('Clean', 'None') and does Forward with performance 203
# <Agent> perceives ('Clean', 'None') and does Forward with performance 202
# <Agent> perceives ('Clean', 'None') and does Forward with performance 201
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 200
# <Agent> perceives ('Clean', 'None') and does Forward with performance 199
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 198
# <Agent> perceives ('Clean', 'None') and does Forward with performance 197
# <Agent> perceives ('Clean', 'None') and does Forward with performance 196
# <Agent> perceives ('Clean', 'None') and does Forward with performance 195
# <Agent> perceives ('Clean', 'None') and does Forward with performance 194
# <Agent> perceives ('Clean', 'None') and does Forward with performance 193
# <Agent> perceives ('Clean', 'None') and does Forward with performance 192
# <Agent> perceives ('Clean', 'None') and does Forward with performance 191
# <Agent> perceives ('Clean', 'None') and does Forward with performance 190
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 189
# <Agent> perceives ('Clean', 'None') and does Forward with performance 188
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 187
# <Agent> perceives ('Clean', 'None') and does Forward with performance 186
# <Agent> perceives ('Clean', 'None') and does Forward with performance 185
# <Agent> perceives ('Clean', 'None') and does Forward with performance 184
# <Agent> perceives ('Clean', 'None') and does Forward with performance 183
# <Agent> perceives ('Clean', 'None') and does Forward with performance 182
# <Agent> perceives ('Clean', 'None') and does Forward with performance 181
# <Agent> perceives ('Clean', 'None') and does Forward with performance 180
# <Agent> perceives ('Clean', 'None') and does Forward with performance 179
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 178
# <Agent> perceives ('Clean', 'None') and does Forward with performance 177
# <Agent> perceives ('Clean', 'None') and does Forward with performance 176
# <Agent> perceives ('Clean', 'None') and does Forward with performance 175
# <Agent> perceives ('Clean', 'None') and does Forward with performance 174
# <Agent> perceives ('Clean', 'None') and does Forward with performance 173
# <Agent> perceives ('Clean', 'None') and does Forward with performance 172
# <Agent> perceives ('Clean', 'None') and does Forward with performance 171
# <Agent> perceives ('Clean', 'None') and does Forward with performance 170
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 169
# <Agent> perceives ('Clean', 'None') and does Forward with performance 168
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 167
# <Agent> perceives ('Clean', 'None') and does Forward with performance 166
# <Agent> perceives ('Clean', 'None') and does Forward with performance 165
# <Agent> perceives ('Clean', 'None') and does Forward with performance 164
# <Agent> perceives ('Clean', 'None') and does Forward with performance 163
# <Agent> perceives ('Clean', 'None') and does Forward with performance 162
# <Agent> perceives ('Clean', 'None') and does Forward with performance 161
# <Agent> perceives ('Clean', 'None') and does Forward with performance 160
# <Agent> perceives ('Clean', 'None') and does Forward with performance 159
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 158
# <Agent> perceives ('Clean', 'None') and does Forward with performance 157
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 156
# <Agent> perceives ('Clean', 'None') and does Forward with performance 155
# <Agent> perceives ('Clean', 'None') and does Forward with performance 154
# <Agent> perceives ('Clean', 'None') and does Forward with performance 153
# <Agent> perceives ('Clean', 'None') and does Forward with performance 152
# <Agent> perceives ('Clean', 'None') and does Forward with performance 151
# <Agent> perceives ('Clean', 'None') and does Forward with performance 150
# <Agent> perceives ('Clean', 'None') and does Forward with performance 149
# <Agent> perceives ('Clean', 'None') and does Forward with performance 148
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 147
# <Agent> perceives ('Clean', 'None') and does Forward with performance 146
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 145
# <Agent> perceives ('Clean', 'None') and does Forward with performance 144
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 143
# <Agent> perceives ('Clean', 'None') and does Forward with performance 142
# <Agent> perceives ('Clean', 'None') and does Forward with performance 141
# <Agent> perceives ('Clean', 'None') and does Forward with performance 140
# <Agent> perceives ('Clean', 'None') and does Forward with performance 139
# <Agent> perceives ('Clean', 'None') and does Forward with performance 138
# <Agent> perceives ('Clean', 'None') and does Forward with performance 137
# <Agent> perceives ('Clean', 'None') and does Forward with performance 136
# <Agent> perceives ('Clean', 'None') and does Forward with performance 135
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 134
# <Agent> perceives ('Clean', 'None') and does Forward with performance 133
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 132
# <Agent> perceives ('Clean', 'None') and does Forward with performance 131
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 130
# <Agent> perceives ('Clean', 'None') and does Forward with performance 129
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 128
# <Agent> perceives ('Clean', 'None') and does Forward with performance 127
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 126
# <Agent> perceives ('Clean', 'None') and does Forward with performance 125
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 124
# <Agent> perceives ('Clean', 'None') and does Forward with performance 123
# <Agent> perceives ('Clean', 'None') and does Forward with performance 122
# <Agent> perceives ('Clean', 'None') and does Forward with performance 121
# <Agent> perceives ('Clean', 'None') and does Forward with performance 120
# <Agent> perceives ('Clean', 'None') and does Forward with performance 119
# <Agent> perceives ('Clean', 'None') and does Forward with performance 118
# <Agent> perceives ('Clean', 'None') and does Forward with performance 117
# <Agent> perceives ('Clean', 'None') and does Forward with performance 116
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 115
# <Agent> perceives ('Clean', 'None') and does Forward with performance 114
# <Agent> perceives ('Clean', 'None') and does Forward with performance 113
# <Agent> perceives ('Clean', 'None') and does Forward with performance 112
# <Agent> perceives ('Clean', 'None') and does Forward with performance 111
# <Agent> perceives ('Clean', 'None') and does Forward with performance 110
# <Agent> perceives ('Clean', 'None') and does Forward with performance 109
# <Agent> perceives ('Clean', 'None') and does Forward with performance 108
# <Agent> perceives ('Clean', 'None') and does Forward with performance 107
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 106
# <Agent> perceives ('Clean', 'None') and does Forward with performance 105
# <Agent> perceives ('Clean', 'None') and does Forward with performance 104
# <Agent> perceives ('Clean', 'None') and does Forward with performance 103
# <Agent> perceives ('Clean', 'None') and does Forward with performance 102
# <Agent> perceives ('Clean', 'None') and does Forward with performance 101
# <Agent> perceives ('Clean', 'None') and does Forward with performance 100
# <Agent> perceives ('Clean', 'None') and does Forward with performance 99
# <Agent> perceives ('Clean', 'None') and does Forward with performance 98
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 97
# <Agent> perceives ('Clean', 'None') and does Forward with performance 96
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 95
# <Agent> perceives ('Clean', 'None') and does Forward with performance 94
# <Agent> perceives ('Clean', 'None') and does Forward with performance 93
# <Agent> perceives ('Clean', 'None') and does Forward with performance 92
# <Agent> perceives ('Clean', 'None') and does Forward with performance 91
# <Agent> perceives ('Clean', 'None') and does Forward with performance 90
# <Agent> perceives ('Clean', 'None') and does Forward with performance 89
# <Agent> perceives ('Clean', 'None') and does Forward with performance 88
# <Agent> perceives ('Clean', 'None') and does Forward with performance 87
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 86
# <Agent> perceives ('Clean', 'None') and does Forward with performance 85
# <Agent> perceives ('Clean', 'None') and does Forward with performance 84
# <Agent> perceives ('Clean', 'None') and does Forward with performance 83
# <Agent> perceives ('Clean', 'None') and does Forward with performance 82
# <Agent> perceives ('Clean', 'None') and does Forward with performance 81
# <Agent> perceives ('Clean', 'None') and does Forward with performance 80
# <Agent> perceives ('Clean', 'None') and does Forward with performance 79
# <Agent> perceives ('Clean', 'None') and does Forward with performance 78
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 77
# <Agent> perceives ('Clean', 'None') and does Forward with performance 76
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 75
# <Agent> perceives ('Clean', 'None') and does Forward with performance 74
# <Agent> perceives ('Clean', 'None') and does Forward with performance 73
# <Agent> perceives ('Clean', 'None') and does Forward with performance 72
# <Agent> perceives ('Clean', 'None') and does Forward with performance 71
# <Agent> perceives ('Clean', 'None') and does Forward with performance 70
# <Agent> perceives ('Clean', 'None') and does Forward with performance 69
# <Agent> perceives ('Clean', 'None') and does Forward with performance 68
# <Agent> perceives ('Clean', 'None') and does Forward with performance 67
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 66
# <Agent> perceives ('Clean', 'None') and does Forward with performance 65
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 64
# <Agent> perceives ('Clean', 'None') and does Forward with performance 63
# <Agent> perceives ('Clean', 'None') and does Forward with performance 62
# <Agent> perceives ('Clean', 'None') and does Forward with performance 61
# <Agent> perceives ('Clean', 'None') and does Forward with performance 60
# <Agent> perceives ('Clean', 'None') and does Forward with performance 59
# <Agent> perceives ('Clean', 'None') and does Forward with performance 58
# <Agent> perceives ('Clean', 'None') and does Forward with performance 57
# <Agent> perceives ('Clean', 'None') and does Forward with performance 56
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 55
# <Agent> perceives ('Clean', 'None') and does Forward with performance 54
# <Agent> perceives ('Clean', 'None') and does Forward with performance 53
# <Agent> perceives ('Clean', 'None') and does Forward with performance 52
# <Agent> perceives ('Clean', 'None') and does Forward with performance 51
# <Agent> perceives ('Clean', 'None') and does Forward with performance 50
# <Agent> perceives ('Clean', 'None') and does Forward with performance 49
# <Agent> perceives ('Clean', 'None') and does Forward with performance 48
# <Agent> perceives ('Clean', 'None') and does Forward with performance 47
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 46
# <Agent> perceives ('Clean', 'None') and does Forward with performance 45
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 44
# <Agent> perceives ('Clean', 'None') and does Forward with performance 43
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 42
# <Agent> perceives ('Clean', 'None') and does Forward with performance 41
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 40
# <Agent> perceives ('Clean', 'None') and does Forward with performance 39
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 38
# <Agent> perceives ('Clean', 'None') and does Forward with performance 37
# <Agent> perceives ('Clean', 'None') and does Forward with performance 36
# <Agent> perceives ('Clean', 'None') and does Forward with performance 35
# <Agent> perceives ('Clean', 'None') and does Forward with performance 34
# <Agent> perceives ('Clean', 'None') and does Forward with performance 33
# <Agent> perceives ('Clean', 'None') and does Forward with performance 32
# <Agent> perceives ('Clean', 'None') and does Forward with performance 31
# <Agent> perceives ('Clean', 'None') and does Forward with performance 30
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 29
# <Agent> perceives ('Clean', 'None') and does Forward with performance 28
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 27
# <Agent> perceives ('Clean', 'None') and does Forward with performance 26
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 25
# <Agent> perceives ('Clean', 'None') and does Forward with performance 24
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 23
# <Agent> perceives ('Clean', 'None') and does Forward with performance 22
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 21
# <Agent> perceives ('Clean', 'None') and does Forward with performance 20
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 19
# <Agent> perceives ('Clean', 'None') and does Forward with performance 18
# <Agent> perceives ('Clean', 'None') and does Forward with performance 17
# <Agent> perceives ('Clean', 'None') and does Forward with performance 16
# <Agent> perceives ('Clean', 'None') and does Forward with performance 15
# <Agent> perceives ('Clean', 'None') and does Forward with performance 14
# <Agent> perceives ('Clean', 'None') and does Forward with performance 13
# <Agent> perceives ('Clean', 'None') and does Forward with performance 12
# <Agent> perceives ('Clean', 'None') and does Forward with performance 11
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 10
# <Agent> perceives ('Clean', 'None') and does Forward with performance 9
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 8
# <Agent> perceives ('Clean', 'None') and does Forward with performance 7
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance 6
# <Agent> perceives ('Clean', 'None') and does Forward with performance 5
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 4
# <Agent> perceives ('Clean', 'None') and does Forward with performance 3
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance 2
# <Agent> perceives ('Clean', 'None') and does Forward with performance 1
# <Agent> perceives ('Clean', 'None') and does Forward with performance 0
# <Agent> perceives ('Clean', 'None') and does Forward with performance -1
# <Agent> perceives ('Clean', 'None') and does Forward with performance -2
# <Agent> perceives ('Clean', 'None') and does Forward with performance -3
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4
# <Agent> perceives ('Clean', 'None') and does Forward with performance -5
# <Agent> perceives ('Clean', 'None') and does Forward with performance -6
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -7
# <Agent> perceives ('Clean', 'None') and does Forward with performance -8
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -9
# <Agent> perceives ('Clean', 'None') and does Forward with performance -10
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -11
# <Agent> perceives ('Clean', 'None') and does Forward with performance -12
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -13
# <Agent> perceives ('Clean', 'None') and does Forward with performance -14
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -15
# <Agent> perceives ('Clean', 'None') and does Forward with performance -16
# <Agent> perceives ('Clean', 'None') and does Forward with performance -17
# <Agent> perceives ('Clean', 'None') and does Forward with performance -18
# <Agent> perceives ('Clean', 'None') and does Forward with performance -19
# <Agent> perceives ('Clean', 'None') and does Forward with performance -20
# <Agent> perceives ('Clean', 'None') and does Forward with performance -21
# <Agent> perceives ('Clean', 'None') and does Forward with performance -22
# <Agent> perceives ('Clean', 'None') and does Forward with performance -23
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -24
# <Agent> perceives ('Clean', 'None') and does Forward with performance -25
# <Agent> perceives ('Clean', 'None') and does Forward with performance -26
# <Agent> perceives ('Clean', 'None') and does Forward with performance -27
# <Agent> perceives ('Clean', 'None') and does Forward with performance -28
# <Agent> perceives ('Clean', 'None') and does Forward with performance -29
# <Agent> perceives ('Clean', 'None') and does Forward with performance -30
# <Agent> perceives ('Clean', 'None') and does Forward with performance -31
# <Agent> perceives ('Clean', 'None') and does Forward with performance -32
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -33
# <Agent> perceives ('Clean', 'None') and does Forward with performance -34
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -35
# <Agent> perceives ('Clean', 'None') and does Forward with performance -36
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -37
# <Agent> perceives ('Clean', 'None') and does Forward with performance -38
# <Agent> perceives ('Clean', 'None') and does Forward with performance -39
# <Agent> perceives ('Clean', 'None') and does Forward with performance -40
# <Agent> perceives ('Clean', 'None') and does Forward with performance -41
# <Agent> perceives ('Clean', 'None') and does Forward with performance -42
# <Agent> perceives ('Clean', 'None') and does Forward with performance -43
# <Agent> perceives ('Clean', 'None') and does Forward with performance -44
# <Agent> perceives ('Clean', 'None') and does Forward with performance -45
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -46
# <Agent> perceives ('Clean', 'None') and does Forward with performance -47
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -48
# <Agent> perceives ('Clean', 'None') and does Forward with performance -49
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -50
# <Agent> perceives ('Clean', 'None') and does Forward with performance -51
# <Agent> perceives ('Clean', 'None') and does Forward with performance -52
# <Agent> perceives ('Clean', 'None') and does Forward with performance -53
# <Agent> perceives ('Clean', 'None') and does Forward with performance -54
# <Agent> perceives ('Clean', 'None') and does Forward with performance -55
# <Agent> perceives ('Clean', 'None') and does Forward with performance -56
# <Agent> perceives ('Clean', 'None') and does Forward with performance -57
# <Agent> perceives ('Clean', 'None') and does Forward with performance -58
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -59
# <Agent> perceives ('Clean', 'None') and does Forward with performance -60
# <Agent> perceives ('Clean', 'None') and does Forward with performance -61
# <Agent> perceives ('Clean', 'None') and does Forward with performance -62
# <Agent> perceives ('Clean', 'None') and does Forward with performance -63
# <Agent> perceives ('Clean', 'None') and does Forward with performance -64
# <Agent> perceives ('Clean', 'None') and does Forward with performance -65
# <Agent> perceives ('Clean', 'None') and does Forward with performance -66
# <Agent> perceives ('Clean', 'None') and does Forward with performance -67
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -68
# <Agent> perceives ('Clean', 'None') and does Forward with performance -69
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -70
# <Agent> perceives ('Clean', 'None') and does Forward with performance -71
# <Agent> perceives ('Clean', 'None') and does Forward with performance -72
# <Agent> perceives ('Clean', 'None') and does Forward with performance -73
# <Agent> perceives ('Clean', 'None') and does Forward with performance -74
# <Agent> perceives ('Clean', 'None') and does Forward with performance -75
# <Agent> perceives ('Clean', 'None') and does Forward with performance -76
# <Agent> perceives ('Clean', 'None') and does Forward with performance -77
# <Agent> perceives ('Clean', 'None') and does Forward with performance -78
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -79
# <Agent> perceives ('Clean', 'None') and does Forward with performance -80
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -81
# <Agent> perceives ('Clean', 'None') and does Forward with performance -82
# <Agent> perceives ('Clean', 'None') and does Forward with performance -83
# <Agent> perceives ('Clean', 'None') and does Forward with performance -84
# <Agent> perceives ('Clean', 'None') and does Forward with performance -85
# <Agent> perceives ('Clean', 'None') and does Forward with performance -86
# <Agent> perceives ('Clean', 'None') and does Forward with performance -87
# <Agent> perceives ('Clean', 'None') and does Forward with performance -88
# <Agent> perceives ('Clean', 'None') and does Forward with performance -89
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -90
# <Agent> perceives ('Clean', 'None') and does Forward with performance -91
# <Agent> perceives ('Clean', 'None') and does Forward with performance -92
# <Agent> perceives ('Clean', 'None') and does Forward with performance -93
# <Agent> perceives ('Clean', 'None') and does Forward with performance -94
# <Agent> perceives ('Clean', 'None') and does Forward with performance -95
# <Agent> perceives ('Clean', 'None') and does Forward with performance -96
# <Agent> perceives ('Clean', 'None') and does Forward with performance -97
# <Agent> perceives ('Clean', 'None') and does Forward with performance -98
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -99
# <Agent> perceives ('Clean', 'None') and does Forward with performance -100
# <Agent> perceives ('Clean', 'None') and does Forward with performance -101
# <Agent> perceives ('Clean', 'None') and does Forward with performance -102
# <Agent> perceives ('Clean', 'None') and does Forward with performance -103
# <Agent> perceives ('Clean', 'None') and does Forward with performance -104
# <Agent> perceives ('Clean', 'None') and does Forward with performance -105
# <Agent> perceives ('Clean', 'None') and does Forward with performance -106
# <Agent> perceives ('Clean', 'None') and does Forward with performance -107
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -108
# <Agent> perceives ('Clean', 'None') and does Forward with performance -109
# <Agent> perceives ('Clean', 'None') and does Forward with performance -110
# <Agent> perceives ('Clean', 'None') and does Forward with performance -111
# <Agent> perceives ('Clean', 'None') and does Forward with performance -112
# <Agent> perceives ('Clean', 'None') and does Forward with performance -113
# <Agent> perceives ('Clean', 'None') and does Forward with performance -114
# <Agent> perceives ('Clean', 'None') and does Forward with performance -115
# <Agent> perceives ('Clean', 'None') and does Forward with performance -116
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -117
# <Agent> perceives ('Clean', 'None') and does Forward with performance -118
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -119
# <Agent> perceives ('Clean', 'None') and does Forward with performance -120
# <Agent> perceives ('Clean', 'None') and does Forward with performance -121
# <Agent> perceives ('Clean', 'None') and does Forward with performance -122
# <Agent> perceives ('Clean', 'None') and does Forward with performance -123
# <Agent> perceives ('Clean', 'None') and does Forward with performance -124
# <Agent> perceives ('Clean', 'None') and does Forward with performance -125
# <Agent> perceives ('Clean', 'None') and does Forward with performance -126
# <Agent> perceives ('Clean', 'None') and does Forward with performance -127
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -128
# <Agent> perceives ('Clean', 'None') and does Forward with performance -129
# <Agent> perceives ('Clean', 'None') and does Forward with performance -130
# <Agent> perceives ('Clean', 'None') and does Forward with performance -131
# <Agent> perceives ('Clean', 'None') and does Forward with performance -132
# <Agent> perceives ('Clean', 'None') and does Forward with performance -133
# <Agent> perceives ('Clean', 'None') and does Forward with performance -134
# <Agent> perceives ('Clean', 'None') and does Forward with performance -135
# <Agent> perceives ('Clean', 'None') and does Forward with performance -136
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -137
# <Agent> perceives ('Clean', 'None') and does Forward with performance -138
# <Agent> perceives ('Clean', 'None') and does Forward with performance -139
# <Agent> perceives ('Clean', 'None') and does Forward with performance -140
# <Agent> perceives ('Clean', 'None') and does Forward with performance -141
# <Agent> perceives ('Clean', 'None') and does Forward with performance -142
# <Agent> perceives ('Clean', 'None') and does Forward with performance -143
# <Agent> perceives ('Clean', 'None') and does Forward with performance -144
# <Agent> perceives ('Clean', 'None') and does Forward with performance -145
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -146
# <Agent> perceives ('Clean', 'None') and does Forward with performance -147
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -148
# <Agent> perceives ('Clean', 'None') and does Forward with performance -149
# <Agent> perceives ('Clean', 'None') and does Forward with performance -150
# <Agent> perceives ('Clean', 'None') and does Forward with performance -151
# <Agent> perceives ('Clean', 'None') and does Forward with performance -152
# <Agent> perceives ('Clean', 'None') and does Forward with performance -153
# <Agent> perceives ('Clean', 'None') and does Forward with performance -154
# <Agent> perceives ('Clean', 'None') and does Forward with performance -155
# <Agent> perceives ('Clean', 'None') and does Forward with performance -156
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -157
# <Agent> perceives ('Clean', 'None') and does Forward with performance -158
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -159
# <Agent> perceives ('Clean', 'None') and does Forward with performance -160
# <Agent> perceives ('Clean', 'None') and does Forward with performance -161
# <Agent> perceives ('Clean', 'None') and does Forward with performance -162
# <Agent> perceives ('Clean', 'None') and does Forward with performance -163
# <Agent> perceives ('Clean', 'None') and does Forward with performance -164
# <Agent> perceives ('Clean', 'None') and does Forward with performance -165
# <Agent> perceives ('Clean', 'None') and does Forward with performance -166
# <Agent> perceives ('Clean', 'None') and does Forward with performance -167
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -168
# <Agent> perceives ('Clean', 'None') and does Forward with performance -169
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -170
# <Agent> perceives ('Clean', 'None') and does Forward with performance -171
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -172
# <Agent> perceives ('Clean', 'None') and does Forward with performance -173
# <Agent> perceives ('Clean', 'None') and does Forward with performance -174
# <Agent> perceives ('Clean', 'None') and does Forward with performance -175
# <Agent> perceives ('Clean', 'None') and does Forward with performance -176
# <Agent> perceives ('Clean', 'None') and does Forward with performance -177
# <Agent> perceives ('Clean', 'None') and does Forward with performance -178
# <Agent> perceives ('Clean', 'None') and does Forward with performance -179
# <Agent> perceives ('Clean', 'None') and does Forward with performance -180
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -181
# <Agent> perceives ('Clean', 'None') and does Forward with performance -182
# <Agent> perceives ('Clean', 'None') and does Forward with performance -183
# <Agent> perceives ('Clean', 'None') and does Forward with performance -184
# <Agent> perceives ('Clean', 'None') and does Forward with performance -185
# <Agent> perceives ('Clean', 'None') and does Forward with performance -186
# <Agent> perceives ('Clean', 'None') and does Forward with performance -187
# <Agent> perceives ('Clean', 'None') and does Forward with performance -188
# <Agent> perceives ('Clean', 'None') and does Forward with performance -189
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -190
# <Agent> perceives ('Clean', 'None') and does Forward with performance -191
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -192
# <Agent> perceives ('Clean', 'None') and does Forward with performance -193
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -194
# <Agent> perceives ('Clean', 'None') and does Forward with performance -195
# <Agent> perceives ('Clean', 'None') and does Forward with performance -196
# <Agent> perceives ('Clean', 'None') and does Forward with performance -197
# <Agent> perceives ('Clean', 'None') and does Forward with performance -198
# <Agent> perceives ('Clean', 'None') and does Forward with performance -199
# <Agent> perceives ('Clean', 'None') and does Forward with performance -200
# <Agent> perceives ('Clean', 'None') and does Forward with performance -201
# <Agent> perceives ('Clean', 'None') and does Forward with performance -202
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -203
# <Agent> perceives ('Clean', 'None') and does Forward with performance -204
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -205
# <Agent> perceives ('Clean', 'None') and does Forward with performance -206
# <Agent> perceives ('Clean', 'None') and does Forward with performance -207
# <Agent> perceives ('Clean', 'None') and does Forward with performance -208
# <Agent> perceives ('Clean', 'None') and does Forward with performance -209
# <Agent> perceives ('Clean', 'None') and does Forward with performance -210
# <Agent> perceives ('Clean', 'None') and does Forward with performance -211
# <Agent> perceives ('Clean', 'None') and does Forward with performance -212
# <Agent> perceives ('Clean', 'None') and does Forward with performance -213
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -214
# <Agent> perceives ('Clean', 'None') and does Forward with performance -215
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -216
# <Agent> perceives ('Clean', 'None') and does Forward with performance -217
# <Agent> perceives ('Clean', 'None') and does Forward with performance -218
# <Agent> perceives ('Clean', 'None') and does Forward with performance -219
# <Agent> perceives ('Clean', 'None') and does Forward with performance -220
# <Agent> perceives ('Clean', 'None') and does Forward with performance -221
# <Agent> perceives ('Clean', 'None') and does Forward with performance -222
# <Agent> perceives ('Clean', 'None') and does Forward with performance -223
# <Agent> perceives ('Clean', 'None') and does Forward with performance -224
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -225
# <Agent> perceives ('Clean', 'None') and does Forward with performance -226
# <Agent> perceives ('Clean', 'None') and does Forward with performance -227
# <Agent> perceives ('Clean', 'None') and does Forward with performance -228
# <Agent> perceives ('Clean', 'None') and does Forward with performance -229
# <Agent> perceives ('Clean', 'None') and does Forward with performance -230
# <Agent> perceives ('Clean', 'None') and does Forward with performance -231
# <Agent> perceives ('Clean', 'None') and does Forward with performance -232
# <Agent> perceives ('Clean', 'None') and does Forward with performance -233
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -234
# <Agent> perceives ('Clean', 'None') and does Forward with performance -235
# <Agent> perceives ('Clean', 'None') and does Forward with performance -236
# <Agent> perceives ('Clean', 'None') and does Forward with performance -237
# <Agent> perceives ('Clean', 'None') and does Forward with performance -238
# <Agent> perceives ('Clean', 'None') and does Forward with performance -239
# <Agent> perceives ('Clean', 'None') and does Forward with performance -240
# <Agent> perceives ('Clean', 'None') and does Forward with performance -241
# <Agent> perceives ('Clean', 'None') and does Forward with performance -242
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -243
# <Agent> perceives ('Clean', 'None') and does Forward with performance -244
# <Agent> perceives ('Clean', 'None') and does Forward with performance -245
# ...
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4391
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4392
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4393
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4394
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4395
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4396
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4397
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4398
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4399
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4400
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4401
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4402
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4403
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4404
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4405
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4406
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4407
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4408
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4409
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4410
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4411
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4412
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4413
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4414
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4415
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4416
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4417
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4418
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4419
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4420
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4421
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4422
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4423
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4424
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4425
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4426
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4427
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4428
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4429
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4430
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4431
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4432
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4433
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4434
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4435
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4436
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4437
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4438
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4439
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4440
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4441
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4442
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4443
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4444
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4445
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4446
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4447
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4448
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4449
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4450
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4451
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4452
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4453
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4454
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4455
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4456
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4457
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4458
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4459
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4460
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4461
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4462
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4463
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4464
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4465
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4466
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4467
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4468
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4469
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4470
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4471
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4472
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4473
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4474
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4475
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4476
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4477
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4478
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4479
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4480
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4481
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4482
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4483
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4484
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4485
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4486
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4487
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4488
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4489
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4490
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4491
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4492
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4493
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4494
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4495
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4496
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4497
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4498
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4499
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4500
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4501
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4502
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4503
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4504
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4505
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4506
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4507
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4508
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4509
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4510
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4511
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4512
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4513
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4514
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4515
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4516
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4517
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4518
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4519
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4520
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4521
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4522
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4523
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4524
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4525
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4526
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4527
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4528
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4529
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4530
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4531
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4532
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4533
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4534
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4535
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4536
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4537
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4538
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4539
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4540
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4541
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4542
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4543
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4544
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4545
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4546
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4547
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4548
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4549
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4550
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4551
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4552
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4553
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4554
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4555
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4556
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4557
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4558
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4559
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4560
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4561
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4562
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4563
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4564
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4565
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4566
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4567
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4568
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4569
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4570
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4571
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4572
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4573
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4574
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4575
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4576
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4577
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4578
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4579
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4580
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4581
# <Agent> perceives ('Clean', 'Bump') and does TurnLeft with performance -4582
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4583
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4584
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4585
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4586
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4587
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4588
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4589
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4590
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4591
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4592
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4593
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4594
# <Agent> perceives ('Clean', 'Bump') and does TurnRight with performance -4595
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4596
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4597
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4598
# <Agent> perceives ('Clean', 'None') and does Forward with performance -4599

# %%
agent.performance
# Out:
# -978

# %%
show_dirt(environment)
# Out:
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', 'DIRT', 'DIRT', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', 'DIRT', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', 'DIRT', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']
# [' c  ', ' c  ', 'DIRT', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ', ' c  ']

# %% [markdown]
# #### Performance
# It kind of sucks. My vacuum ins't smart enough.

# %% [markdown]
# ## MODEL-BASED REFLEX AGENTS
#
# Let's recall the diagram for the simple reflex agent
#
# <p align="center">
# <img src="images/simple_reflex_agent.jpg">
# </p>
#
# and compare to this new model-based agent
#
# <p align="center">
# <img src="images/model_based_reflex_agent.jpg">
# </p>
#
# and you can see that now the robot is trying to form a model to understand the consequences of its actions.

# %%
psource(ModelBasedReflexAgentProgram)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">ModelBasedReflexAgentProgram</span><span class="p">(</span><span class="n">rules</span><span class="p">,</span> <span class="n">update_state</span><span class="p">,</span> <span class="n">transition_model</span><span class="p">,</span> <span class="n">sensor_model</span><span class="p">):</span>
#     <span class="sd">&quot;&quot;&quot;</span>
# <span class="sd">    [Figure 2.12]</span>
# <span class="sd">    This agent takes action based on the percept and state.</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#
#     <span class="k">def</span> <span class="nf">program</span><span class="p">(</span><span class="n">percept</span><span class="p">):</span>
#         <span class="n">program</span><span class="o">.</span><span class="n">state</span> <span class="o">=</span> <span class="n">update_state</span><span class="p">(</span><span class="n">program</span><span class="o">.</span><span class="n">state</span><span class="p">,</span> <span class="n">program</span><span class="o">.</span><span class="n">action</span><span class="p">,</span> <span class="n">percept</span><span class="p">,</span> <span class="n">transition_model</span><span class="p">,</span> <span class="n">sensor_model</span><span class="p">)</span>
#         <span class="n">rule</span> <span class="o">=</span> <span class="n">rule_match</span><span class="p">(</span><span class="n">program</span><span class="o">.</span><span class="n">state</span><span class="p">,</span> <span class="n">rules</span><span class="p">)</span>
#         <span class="n">action</span> <span class="o">=</span> <span class="n">rule</span><span class="o">.</span><span class="n">action</span>
#         <span class="k">return</span> <span class="n">action</span>
#
#     <span class="n">program</span><span class="o">.</span><span class="n">state</span> <span class="o">=</span> <span class="n">program</span><span class="o">.</span><span class="n">action</span> <span class="o">=</span> <span class="kc">None</span>
#     <span class="k">return</span> <span class="n">program</span>
# </pre></div>
# </body>
# </html>

# %% [markdown]
# ### Trivial Model-Based Vacuum Agent

# %%
psource(ModelBasedVacuumAgent)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #ffffcc }
# body { background: #f8f8f8; }
# body .c { color: #3D7B7B; font-style: italic } /* Comment */
# body .err { border: 1px solid #FF0000 } /* Error */
# body .k { color: #008000; font-weight: bold } /* Keyword */
# body .o { color: #666666 } /* Operator */
# body .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# body .cp { color: #9C6500 } /* Comment.Preproc */
# body .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# body .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# body .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# body .gd { color: #A00000 } /* Generic.Deleted */
# body .ge { font-style: italic } /* Generic.Emph */
# body .gr { color: #E40000 } /* Generic.Error */
# body .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# body .gi { color: #008400 } /* Generic.Inserted */
# body .go { color: #717171 } /* Generic.Output */
# body .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# body .gs { font-weight: bold } /* Generic.Strong */
# body .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# body .gt { color: #0044DD } /* Generic.Traceback */
# body .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# body .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# body .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# body .kp { color: #008000 } /* Keyword.Pseudo */
# body .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# body .kt { color: #B00040 } /* Keyword.Type */
# body .m { color: #666666 } /* Literal.Number */
# body .s { color: #BA2121 } /* Literal.String */
# body .na { color: #687822 } /* Name.Attribute */
# body .nb { color: #008000 } /* Name.Builtin */
# body .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# body .no { color: #880000 } /* Name.Constant */
# body .nd { color: #AA22FF } /* Name.Decorator */
# body .ni { color: #717171; font-weight: bold } /* Name.Entity */
# body .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# body .nf { color: #0000FF } /* Name.Function */
# body .nl { color: #767600 } /* Name.Label */
# body .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# body .nt { color: #008000; font-weight: bold } /* Name.Tag */
# body .nv { color: #19177C } /* Name.Variable */
# body .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# body .w { color: #bbbbbb } /* Text.Whitespace */
# body .mb { color: #666666 } /* Literal.Number.Bin */
# body .mf { color: #666666 } /* Literal.Number.Float */
# body .mh { color: #666666 } /* Literal.Number.Hex */
# body .mi { color: #666666 } /* Literal.Number.Integer */
# body .mo { color: #666666 } /* Literal.Number.Oct */
# body .sa { color: #BA2121 } /* Literal.String.Affix */
# body .sb { color: #BA2121 } /* Literal.String.Backtick */
# body .sc { color: #BA2121 } /* Literal.String.Char */
# body .dl { color: #BA2121 } /* Literal.String.Delimiter */
# body .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# body .s2 { color: #BA2121 } /* Literal.String.Double */
# body .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# body .sh { color: #BA2121 } /* Literal.String.Heredoc */
# body .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# body .sx { color: #008000 } /* Literal.String.Other */
# body .sr { color: #A45A77 } /* Literal.String.Regex */
# body .s1 { color: #BA2121 } /* Literal.String.Single */
# body .ss { color: #19177C } /* Literal.String.Symbol */
# body .bp { color: #008000 } /* Name.Builtin.Pseudo */
# body .fm { color: #0000FF } /* Name.Function.Magic */
# body .vc { color: #19177C } /* Name.Variable.Class */
# body .vg { color: #19177C } /* Name.Variable.Global */
# body .vi { color: #19177C } /* Name.Variable.Instance */
# body .vm { color: #19177C } /* Name.Variable.Magic */
# body .il { color: #666666 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">def</span> <span class="nf">ModelBasedVacuumAgent</span><span class="p">():</span>
#     <span class="sd">&quot;&quot;&quot;An agent that keeps track of what locations are clean or dirty.</span>
# <span class="sd">    &gt;&gt;&gt; agent = ModelBasedVacuumAgent()</span>
# <span class="sd">    &gt;&gt;&gt; environment = TrivialVacuumEnvironment()</span>
# <span class="sd">    &gt;&gt;&gt; environment.add_thing(agent)</span>
# <span class="sd">    &gt;&gt;&gt; environment.run()</span>
# <span class="sd">    &gt;&gt;&gt; environment.status == {(1,0):&#39;Clean&#39; , (0,0) : &#39;Clean&#39;}</span>
# <span class="sd">    True</span>
# <span class="sd">    &quot;&quot;&quot;</span>
#     <span class="n">model</span> <span class="o">=</span> <span class="p">{</span><span class="n">loc_A</span><span class="p">:</span> <span class="kc">None</span><span class="p">,</span> <span class="n">loc_B</span><span class="p">:</span> <span class="kc">None</span><span class="p">}</span>
#
#     <span class="k">def</span> <span class="nf">program</span><span class="p">(</span><span class="n">percept</span><span class="p">):</span>
#         <span class="sd">&quot;&quot;&quot;Same as ReflexVacuumAgent, except if everything is clean, do NoOp.&quot;&quot;&quot;</span>
#         <span class="n">location</span><span class="p">,</span> <span class="n">status</span> <span class="o">=</span> <span class="n">percept</span>
#         <span class="n">model</span><span class="p">[</span><span class="n">location</span><span class="p">]</span> <span class="o">=</span> <span class="n">status</span>  <span class="c1"># Update the model here</span>
#         <span class="k">if</span> <span class="n">model</span><span class="p">[</span><span class="n">loc_A</span><span class="p">]</span> <span class="o">==</span> <span class="n">model</span><span class="p">[</span><span class="n">loc_B</span><span class="p">]</span> <span class="o">==</span> <span class="s1">&#39;Clean&#39;</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;NoOp&#39;</span>
#         <span class="k">elif</span> <span class="n">status</span> <span class="o">==</span> <span class="s1">&#39;Dirty&#39;</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;Suck&#39;</span>
#         <span class="k">elif</span> <span class="n">location</span> <span class="o">==</span> <span class="n">loc_A</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;Right&#39;</span>
#         <span class="k">elif</span> <span class="n">location</span> <span class="o">==</span> <span class="n">loc_B</span><span class="p">:</span>
#             <span class="k">return</span> <span class="s1">&#39;Left&#39;</span>
#
#     <span class="k">return</span> <span class="n">Agent</span><span class="p">(</span><span class="n">program</span><span class="p">)</span>
# </pre></div>
# </body>
# </html>

# %% [markdown]
# This really isn't much better -- it just knows not to keep cleaning if it's done. But the environment was already doing that for us, and in my 2D example it couldn't find all of the spots to clean efficiently so it would never stop anyhow. That's because it really needs to figure out which movements were helpful and to then learn how to move more efficiently. To do that we need to incorporate the performance in its movement rules.

# %% [markdown]
# ## GOAL-BASED AGENTS
#
# <p align="center">
# <img src="images/model_based_reflex_agent.jpg">
# </p>
#
# <p align="center">
# <img src="images/model_goal_based_agent.jpg">
# </p>
#
# You can see that we're now allowing ourselves to learn what actions lead to a specific state. So, for example, could we decide which direction to turn based on whether there's a dirty patch to the left or the right.

# %% [markdown]
# ## UTILITY-BASED VS. GOAL-BASED AGENTS
#
# <p align="center">
# <img src="images/model_goal_based_agent.jpg">
# </p>
# <p align="center">
# <img src="images/model_utility_based_agent.jpg">
# </p>
#
# Now we're not focused on landing in a particular state, but rather we're focused on moving towards a state that we like. We'll learn in later sections how you can train a model by moving through your environment and learning which steps *eventually* get you to the state you like. So the **utility** of a move is related to whether it's getting you closer to your end-goal. So could we know that long-term we're more likely to clean the most patches by moving in a consistent way? I think I'm probably getting ahead of myself -- this is all sending us here:k

# %% [markdown]
# ## AGENTS THAT LEARN
#
# <p align="center">
# <img src="images/model_goal_based_agent.jpg">
# </p>
#
# <p align="center">
# <img src="images/general_learning_agent.jpg">
# </p>

# %% [markdown]
# The **learning element** is responsible for making improvements, while the **performance element** actually makes the current choice of action. This latter part is what was the entire agent in previous iterations. On the other hand, the **critic** evaluates the agent's performance (how did the environment change after the agent's last action?) and the learning element uses this feedback to update the logic in the performance element.
#
# The role of the **problem generator** is to figure out what actions we should take so that we learn the most from our experiments.
#
# # How can we best describe that state?
#
# <p align="center">
# <img src="images/atomic-factored-structured.png">
# </p>
#
# ## Atomic
#
# A single string or number or ...
#
# ## Factored representation
#
# A preset list of key-value pairs
#
# ## Structured representation
#
# Describes the relationships between the things in the environment
